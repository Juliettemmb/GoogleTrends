# %%
import pandas as pd
from pytrends.request import TrendReq

# %%
candidate_firstname = "carlos"
candidate_lastname = "Galan"

# %%
df = pd.read_excel("C:/Users/LAURA/Downloads/"+ candidate_lastname +".xlsx")

# %%
df = df[['Palabras','Frequencia']]

# %%
df = df[df['Frequencia']>7]

# %%
pytrends = TrendReq(hl = 'en-US', tz = 360)

# %%
df['Palabras1'] = df['Palabras'].apply(lambda x:x + " " + candidate_firstname)
df['Palabras2'] = df['Palabras'].apply(lambda x:x + " " + candidate_lastname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-f3f4e03a7391> in <module>
# ----> 1 df['Palabras1'] = df['Palabras'].apply(lambda x:x + " " + firstname)
#       2 df['Palabras2'] = df['Palabras'].apply(lambda x:x + " " +lastname)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-81-f3f4e03a7391> in <lambda>(x)
# ----> 1 df['Palabras1'] = df['Palabras'].apply(lambda x:x + " " + firstname)
#       2 df['Palabras2'] = df['Palabras'].apply(lambda x:x + " " +lastname)
#
# NameError: name 'firstname' is not defined

# %%
palabras = list(df['Palabras1']) + list(df['Palabras2'])

# %%
grupos_palabras = list(zip(*[iter(palabras)]*5))
grupos_palabras = [list(x) for x in grupos_palabras]

# %%
grupos_palabras[0]
# Out:
# ['Bogotá galan', 'ciudad galan', 'gente galan', 'hacer galan', 'tiene galan']

# %%
dicti = {}
i = 1
for palabras in grupos_palabras:
    pytrends.build_payload(palabras, timeframe = 'today 5-y', geo = 'CO')
    dicti[i] = pytrends.interest_over_time()
    i+=1

# %%
prueba = pd.concat(dicti, axis=1)
prueba.columns = prueba.columns.droplevel(0)
prueba = prueba.drop(labels = "isPartial", axis = 1)

# %%
prueba
# Out:
#             Bogotá galan  ciudad galan  gente galan  hacer galan  tiene galan  \
# 2014-09-28             0             0            0           59            0
# 2014-10-05            30            30            0           30            0
# 2014-10-12             0             0            0            0            0
# 2014-10-19             0             0            0           28            0
# 2014-10-26             0             0            0            0            0
# ...                  ...           ...          ...          ...          ...
# 2019-08-18            80            24           48            0           48
# 2019-08-25            82            22           22           22           37
# 2019-09-01            44             0           22           22           22
# 2019-09-08            99            22           44           44           22
# 2019-09-15            42             0            0           25           25
#
#             porque galan  Carlos galan  también galan  tenemos galan  \
# 2014-09-28             0             9              0              0
# 2014-10-05             0             8              0              0
# 2014-10-12             1            10              0              0
# 2014-10-19             2            14              0              0
# 2014-10-26             2            12              0              0
# ...                  ...           ...            ...            ...
# 2019-08-18             1           100              0              0
# 2019-08-25             1            32              0              0
# 2019-09-01             1            28              0              0
# 2019-09-08             1            29              0              0
# 2019-09-15             1            37              0              0
#
#             entonces galan  ...  seguridad carlos  política carlos  \
# 2014-09-28               0  ...                32               24
# 2014-10-05               0  ...                25                0
# 2014-10-12               0  ...                25               25
# 2014-10-19               0  ...                23               23
# 2014-10-26               0  ...                32               24
# ...                    ...  ...               ...              ...
# 2019-08-18               0  ...                29               29
# 2019-08-25               0  ...                27               18
# 2019-09-01               0  ...                18               36
# 2019-09-08               0  ...                48               36
# 2019-09-15               0  ...                41               21
#
#             manera carlos  llegar carlos  movilidad carlos  calidad carlos  \
# 2014-09-28              0             24                 0              47
# 2014-10-05              0             25                 0              64
# 2014-10-12              0              0                 0              65
# 2014-10-19             23             23                 0              30
# 2014-10-26              0             24                 0              31
# ...                   ...            ...               ...             ...
# 2019-08-18             39             49                 0              25
# 2019-08-25             37             18                 0               0
# 2019-09-01             18             24                 0              23
# 2019-09-08             18             24                 0               0
# 2019-09-15             21             72                 0              27
#
#             además carlos  obviamente carlos  bicicletas carlos  nadie carlos
# 2014-09-28              0                  0                  0            31
# 2014-10-05              0                  0                  0            32
# 2014-10-12              0                  0                  0            32
# 2014-10-19              0                  0                  0            30
# 2014-10-26              0                  0                  0             0
# ...                   ...                ...                ...           ...
# 2019-08-18              0                  0                  0            25
# 2019-08-25              0                  0                  0            24
# 2019-09-01              0                  0                  0             0
# 2019-09-08              0                  0                  0            23
# 2019-09-15              0                  0                  0            27
#
# [260 rows x 115 columns]

# %%
prueba.to_excel("CarlosGalanGoogleTrends.xlsx")
